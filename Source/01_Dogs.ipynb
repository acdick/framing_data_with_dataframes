# %%
import pandas as pd
import sqlite3

# %% [markdown]
# # NYC Dog Licensing Dataset (ETL): Extract

# %%
#pull and save NYC Dog Licensing Dataset from NYC Open Data
dogs = pd.read_csv("../Data/NYC_Dog_Licensing_Dataset.csv")
print(dogs.shape)
dogs.head()
# Out:
# (121949, 15)
#    RowNumber AnimalName AnimalGender        AnimalBirthMonth  \
# 0        533    BONITA             F  05/01/2013 12:00:00 AM
# 1        548      ROCKY            M  05/01/2014 12:00:00 AM
# 2        622      BULLY            M  07/01/2010 12:00:00 AM
# 3        633      COCO             M  02/01/2005 12:00:00 AM
# 4        655       SKI             F  09/01/2012 12:00:00 AM
#
#                             BreedName Borough  ZipCode  CommunityDistrict  \
# 0                             Unknown  Queens  11435.0              412.0
# 1       Labrador Retriever Crossbreed  Queens  11691.0              414.0
# 2  American Pit Bull Terrier/Pit Bull  Queens  11419.0              410.0
# 3                  Labrador Retriever  Queens  11692.0              414.0
# 4  American Pit Bull Terrier/Pit Bull  Queens  11691.0              414.0
#
#    CensusTract2010   NTA  CityCouncilDistrict  CongressionalDistrict  \
# 0            208.0  QN61                 28.0                    5.0
# 1         100801.0  QN15                 31.0                    5.0
# 2             98.0  QN55                 28.0                    5.0
# 3            964.0  QN12                 31.0                    5.0
# 4         100802.0  QN15                 31.0                    5.0
#
#    StateSenatorialDistrict LicenseIssuedDate LicenseExpiredDate
# 0                     10.0        10/24/2014         11/15/2017
# 1                     10.0        10/25/2014         10/25/2019
# 2                     10.0        10/28/2014         09/24/2016
# 3                     10.0        10/29/2014         10/29/2017
# 4                     10.0        10/31/2014         10/31/2019

# %% [markdown]
# # NYC Dog Licensing Dataset (ETL): Transform

# %%
#drop extraneous columns of dataset
dogs = dogs.drop(['RowNumber',
                  'AnimalBirthMonth',
                  'CommunityDistrict',
                  'CensusTract2010',
                  'NTA',
                  'CityCouncilDistrict',
                  'CongressionalDistrict',
                  'StateSenatorialDistrict'], axis=1)

#drop records with missing data
dogs = dogs.dropna()
print(dogs.shape)

#extract license issued and expired years
dogs['LicenseIssuedYear'] = pd.DatetimeIndex(dogs['LicenseIssuedDate']).year
dogs['LicenseExpiredYear'] = pd.DatetimeIndex(dogs['LicenseExpiredDate']).year

#drop license issued and expired date columns of dataset
dogs = dogs.drop(['LicenseIssuedDate', 'LicenseExpiredDate'], axis=1)

#set integer types
dogs.ZipCode = dogs.ZipCode.astype(int)
dogs.LicenseIssuedYear = dogs.LicenseIssuedYear.astype(int)
dogs.LicenseExpiredYear = dogs.LicenseExpiredYear.astype(int)
# Out:
# (121713, 7)

# %%
#review cleaned dataset
dogs.head()
# Out:
#   AnimalName AnimalGender                           BreedName Borough  \
# 0    BONITA             F                             Unknown  Queens
# 1      ROCKY            M       Labrador Retriever Crossbreed  Queens
# 2      BULLY            M  American Pit Bull Terrier/Pit Bull  Queens
# 3      COCO             M                  Labrador Retriever  Queens
# 4       SKI             F  American Pit Bull Terrier/Pit Bull  Queens
#
#    ZipCode  LicenseIssuedYear  LicenseExpiredYear
# 0    11435               2014                2017
# 1    11691               2014                2019
# 2    11419               2014                2016
# 3    11692               2014                2017
# 4    11691               2014                2019

# %%
#check data types of dataset
dogs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 121713 entries, 0 to 121948
# Data columns (total 7 columns):
# AnimalName            121713 non-null object
# AnimalGender          121713 non-null object
# BreedName             121713 non-null object
# Borough               121713 non-null object
# ZipCode               121713 non-null int64
# LicenseIssuedYear     121713 non-null int64
# LicenseExpiredYear    121713 non-null int64
# dtypes: int64(3), object(4)
# memory usage: 7.4+ MB

# %%
#statistical description of dataset
dogs.describe()
# Out:
#              ZipCode  LicenseIssuedYear  LicenseExpiredYear
# count  121713.000000      121713.000000       121713.000000
# mean    10677.812945        2015.612934         2016.898524
# std       917.666855           0.518188            0.919029
# min       121.000000        2014.000000         2016.000000
# 25%     10029.000000        2015.000000         2016.000000
# 50%     10465.000000        2016.000000         2017.000000
# 75%     11228.000000        2016.000000         2017.000000
# max     94608.000000        2016.000000         2022.000000

# %% [markdown]
# # NYC Dog Licensing Dataset (ETL): Load

# %%
#creating SQL connection
conn = sqlite3.connect('../Data/pet_care_industry.db')
c = conn.cursor()

#function to create table
def create_table(query):
    c.execute(query)

#function to close connection
def close_c_conn():
    c.close()
    conn.close()

# %%
#create dogs table
create_query = """CREATE TABLE dogs
                (id INTEGER PRIMARY KEY,
                 AnimalName TEXT,
                 AnimalGender TEXT,
                 BreedName TEXT,
                 Borough TEXT,
                 ZipCode INTEGER,
                 LicenseIssuedYear INTEGER,
                 LicenseExpiredYear INTEGER);"""

c.execute('DROP TABLE IF EXISTS dogs')
create_table(create_query)

# %%
#function to insert dogs into table
def insert_dogs(dogs):
    for i in range(len(dogs.index)):
        c.execute("""INSERT INTO dogs
                  (id,
                   AnimalName,
                   AnimalGender,
                   BreedName,
                   Borough,
                   ZipCode,
                   LicenseIssuedYear,
                   LicenseExpiredYear)
                   VALUES
                   (?,?,?,?,?,?,?,?)""",
                   (i,
                    dogs.iloc[i]['AnimalName'],
                    dogs.iloc[i]['AnimalGender'],
                    dogs.iloc[i]['BreedName'],
                    dogs.iloc[i]['Borough'],
                    int(dogs.iloc[i]['ZipCode']),
                    int(dogs.iloc[i]['LicenseIssuedYear']),
                    int(dogs.iloc[i]['LicenseExpiredYear'])))
        
    conn.commit()
    
#insert dogs into table
insert_dogs(dogs)

# %%
#check SQL dogs table
pd.read_sql_query("SELECT * FROM dogs;", conn)
# Out:
#             id         AnimalName AnimalGender  \
# 0            0            BONITA             F
# 1            1              ROCKY            M
# 2            2              BULLY            M
# 3            3              COCO             M
# 4            4               SKI             F
# 5            5              CHASE            M
# 6            6             CHEWY             M
# 7            7              CHASE            M
# 8            8              MILEY            F
# 9            9              KENZI            F
# 10          10            APOLLO             M
# 11          11             BELLA             F
# 12          12          PENELOPE             F
# 13          13              JERRY            M
# 14          14              HAZEL            F
# 15          15              SIMON            M
# 16          16           PRINCESS            F
# 17          17             PEPPER            F
# 18          18            PEBBLES            F
# 19          19              BUDDY            M
# 20          20  NAME NOT PROVIDED            F
# 21          21              CODY             M
# 22          22              CHAMP            M
# 23          23                J.D            M
# 24          24             TIGGER            M
# 25          25              KUSH             M
# 26          26            PATCHES            F
# 27          27               LUNA            F
# 28          28             FUDGE             M
# 29          29             CRAZY             F
# ...        ...                ...          ...
# 121683  121683               DOVE            F
# 121684  121684             HENRY             M
# 121685  121685           HEINRICH            M
# 121686  121686             BELLA             F
# 121687  121687             GEORGE            M
# 121688  121688              COSMO            M
# 121689  121689              ROXIE            F
# 121690  121690              ROCKY            M
# 121691  121691             MORGAN            F
# 121692  121692               KOBE            M
# 121693  121693             DOLLY             F
# 121694  121694             APOLLO            M
# 121695  121695              GOOFY            M
# 121696  121696                 CJ            M
# 121697  121697              SARGE            M
# 121698  121698             HUDSON            M
# 121699  121699           GUERIERO            F
# 121700  121700             PHOEBE            F
# 121701  121701            BAILEY             M
# 121702  121702              YODA             M
# 121703  121703             NORMAN            M
# 121704  121704                LEO            M
# 121705  121705              FHAYE            F
# 121706  121706           HOLIDAY             F
# 121707  121707             HENRY             M
# 121708  121708                MIA            F
# 121709  121709              MOCHA            F
# 121710  121710              TEDDY            M
# 121711  121711              SUNNY            M
# 121712  121712             BRODY             M
#
#                                    BreedName        Borough  ZipCode  \
# 0                                    Unknown         Queens    11435
# 1              Labrador Retriever Crossbreed         Queens    11691
# 2         American Pit Bull Terrier/Pit Bull         Queens    11419
# 3                         Labrador Retriever         Queens    11692
# 4         American Pit Bull Terrier/Pit Bull         Queens    11691
# 5                                   Shih Tzu         Queens    11692
# 6                                   Shih Tzu         Queens    11694
# 7                         Labrador Retriever         Queens    11691
# 8                                      Boxer         Queens    11419
# 9                       Schnauzer, Miniature         Queens    11420
# 10        American Pit Bull Terrier/Pit Bull         Queens    11420
# 11                         Yorkshire Terrier         Queens    11434
# 12                         Yorkshire Terrier         Queens    11434
# 13                        Labrador Retriever         Queens    11436
# 14        American Pit Bull Terrier/Pit Bull         Queens    11434
# 15                                  Havanese         Queens    11691
# 16                                  Shih Tzu         Queens    11417
# 17                                  Shih Tzu         Queens    11417
# 18                         Yorkshire Terrier         Queens    11417
# 19             Labrador Retriever Crossbreed         Queens    11692
# 20                                 Chihuahua         Queens    11420
# 21                                Lhasa Apso         Queens    11420
# 22      American Pit Bull Mix / Pit Bull Mix         Queens    11420
# 23                      Jack Russell Terrier         Queens    11434
# 24                      Jack Russell Terrier         Queens    11694
# 25        American Pit Bull Terrier/Pit Bull         Queens    11422
# 26                                   Bulldog         Queens    11691
# 27                         Yorkshire Terrier         Queens    11418
# 28        American Pit Bull Terrier/Pit Bull       Brooklyn    11692
# 29           American Staffordshire Terrier          Queens    11436
# ...                                      ...            ...      ...
